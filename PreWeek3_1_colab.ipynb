# %% [markdown]
# # **Week3授業前課題1 アヤメの分析**

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X = iris.data[:, :]
y = iris.target

# %% [markdown]
# ## **【問題1】データの取得**

# %%
import pandas as pd

X = pd.DataFrame(data=X)
X.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y = pd.DataFrame(data=y)
y.columns = ['Species']
y[:50] = 'setosa'
y[50:100] = 'virgicolor'
y[100:] = 'virginica'
y.head()
# Out:
#   Species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ## **【問題2】データの結合**

# %%
df = pd.concat([X, y], axis=1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## **【問題3】データの確認**

# %%
# 4番目のデータまでを表示
df.head(4)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa

# %%
# 各特徴量がどういったものか
# ラベルsetosa
df0 = df.iloc[:50, :]
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
# sepal_length    50 non-null float64
# sepal_width     50 non-null float64
# petal_length    50 non-null float64
# petal_width     50 non-null float64
# Species         50 non-null object
# dtypes: float64(4), object(1)
# memory usage: 2.0+ KB

# %%
# ラベルvirgicolor
df1 = df.iloc[50:100, :]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 50 to 99
# Data columns (total 5 columns):
# sepal_length    50 non-null float64
# sepal_width     50 non-null float64
# petal_length    50 non-null float64
# petal_width     50 non-null float64
# Species         50 non-null object
# dtypes: float64(4), object(1)
# memory usage: 2.0+ KB

# %%
# ラベルvirginica
df2 = df.iloc[100:, :]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 100 to 149
# Data columns (total 5 columns):
# sepal_length    50 non-null float64
# sepal_width     50 non-null float64
# petal_length    50 non-null float64
# petal_width     50 non-null float64
# Species         50 non-null object
# dtypes: float64(4), object(1)
# memory usage: 2.0+ KB

# %%
# ラベルごとのサンプル数の合計を出力
# ラベルsetosa
df0.sum()
# Out:
# sepal_length                                                250.3
# sepal_width                                                 171.4
# petal_length                                                 73.1
# petal_width                                                  12.3
# Species         setosasetosasetosasetosasetosasetosasetosaseto...
# dtype: object

# %%
# ラベルvirgicolor
df1.sum()
# Out:
# sepal_length                                                296.8
# sepal_width                                                 138.5
# petal_length                                                  213
# petal_width                                                  66.3
# Species         virgicolorvirgicolorvirgicolorvirgicolorvirgic...
# dtype: object

# %%
# ラベルvirginica
df2.sum()
# Out:
# sepal_length                                                329.4
# sepal_width                                                 148.7
# petal_length                                                277.6
# petal_width                                                 101.3
# Species         virginicavirginicavirginicavirginicavirginicav...
# dtype: object

# %%
# 特徴量に欠損値が存在するかを確認
# ラベルsetosa
df0.isnull().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  Species
# 0         False        False         False        False    False
# 1         False        False         False        False    False
# 2         False        False         False        False    False
# 3         False        False         False        False    False
# 4         False        False         False        False    False

# %%
# ラベルvirgicolor
df1.isnull().head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  Species
# 50         False        False         False        False    False
# 51         False        False         False        False    False
# 52         False        False         False        False    False
# 53         False        False         False        False    False
# 54         False        False         False        False    False

# %%
# ラベルvirginica
df2.isnull().head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Species
# 100         False        False         False        False    False
# 101         False        False         False        False    False
# 102         False        False         False        False    False
# 103         False        False         False        False    False
# 104         False        False         False        False    False

# %%
# 特徴量の平均値と標準偏差、四分位数を一度に表示させる
# ラベルsetosa
df0.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %%
# ラベルvirgicolor
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
# ラベルvirginica
df2.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %% [markdown]
# ## **【問題4】irisデータセット自体の調査**

# %% [markdown]
# **Iris setosa** :毛先の尖ったアイリスとして知られる。背の低いものから高いものまで様々に存在する。花びらは幅5~8cm、長さは7~8cmありがく片は非常に小さい。
#
# **Iris virgicolor** :青い花びらが特徴。アメリカ東部やカナダ東部に生息。10~80cmに成長する。6枚の花弁とがく片がある。毒性がある。
#
# **Iris virginica** :花びらは幅4cm以上、長さが7cm以上であり3枚のがく片から成る。花びらとがく片の色は濃い紫からピンクがかった白まで様々。

# %% [markdown]
# ## **【問題5】必要なデータを抽出**

# %%
# sepal_widthの列を3通りの方法で抽出する
# パターン1：ilocを利用して取り出す
df.iloc[:, 1]
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
# 5      3.9
# 6      3.4
# 7      3.4
# 8      2.9
# 9      3.1
# 10     3.7
# 11     3.4
# 12     3.0
# 13     3.0
# 14     4.0
# 15     4.4
# 16     3.9
# 17     3.5
# 18     3.8
# 19     3.8
# 20     3.4
# 21     3.7
# 22     3.6
# 23     3.3
# 24     3.4
# 25     3.0
# 26     3.4
# 27     3.5
# 28     3.4
# 29     3.2
#       ...
# 120    3.2
# 121    2.8
# 122    2.8
# 123    2.7
# 124    3.3
# 125    3.2
# 126    2.8
# 127    3.0
# 128    2.8
# 129    3.0
# 130    2.8
# 131    3.8
# 132    2.8
# 133    2.8
# 134    2.6
# 135    3.0
# 136    3.4
# 137    3.1
# 138    3.0
# 139    3.1
# 140    3.1
# 141    3.1
# 142    2.7
# 143    3.2
# 144    3.3
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
# パターン2：列名で取り出す
df['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
# 5      3.9
# 6      3.4
# 7      3.4
# 8      2.9
# 9      3.1
# 10     3.7
# 11     3.4
# 12     3.0
# 13     3.0
# 14     4.0
# 15     4.4
# 16     3.9
# 17     3.5
# 18     3.8
# 19     3.8
# 20     3.4
# 21     3.7
# 22     3.6
# 23     3.3
# 24     3.4
# 25     3.0
# 26     3.4
# 27     3.5
# 28     3.4
# 29     3.2
#       ...
# 120    3.2
# 121    2.8
# 122    2.8
# 123    2.7
# 124    3.3
# 125    3.2
# 126    2.8
# 127    3.0
# 128    2.8
# 129    3.0
# 130    2.8
# 131    3.8
# 132    2.8
# 133    2.8
# 134    2.6
# 135    3.0
# 136    3.4
# 137    3.1
# 138    3.0
# 139    3.1
# 140    3.1
# 141    3.1
# 142    2.7
# 143    3.2
# 144    3.3
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
# パターン3：locを利用する
df.loc[:, 'sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
# 5      3.9
# 6      3.4
# 7      3.4
# 8      2.9
# 9      3.1
# 10     3.7
# 11     3.4
# 12     3.0
# 13     3.0
# 14     4.0
# 15     4.4
# 16     3.9
# 17     3.5
# 18     3.8
# 19     3.8
# 20     3.4
# 21     3.7
# 22     3.6
# 23     3.3
# 24     3.4
# 25     3.0
# 26     3.4
# 27     3.5
# 28     3.4
# 29     3.2
#       ...
# 120    3.2
# 121    2.8
# 122    2.8
# 123    2.7
# 124    3.3
# 125    3.2
# 126    2.8
# 127    3.0
# 128    2.8
# 129    3.0
# 130    2.8
# 131    3.8
# 132    2.8
# 133    2.8
# 134    2.6
# 135    3.0
# 136    3.4
# 137    3.1
# 138    3.0
# 139    3.1
# 140    3.1
# 141    3.1
# 142    2.7
# 143    3.2
# 144    3.3
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
# 50番目から99番目までのデータを抽出する
df.iloc[50:100, :].head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     Species
# 50           7.0          3.2           4.7          1.4  virgicolor
# 51           6.4          3.2           4.5          1.5  virgicolor
# 52           6.9          3.1           4.9          1.5  virgicolor
# 53           5.5          2.3           4.0          1.3  virgicolor
# 54           6.5          2.8           4.6          1.5  virgicolor

# %%
# petal_lengthの列の50番目から99番目までのデータを抽出する
df.loc[50:100, 'petal_length'].head()
# Out:
# 50    4.7
# 51    4.5
# 52    4.9
# 53    4.0
# 54    4.6
# Name: petal_length, dtype: float64

# %%
# petal_widthの値が0.2のデータを抽出する
df[df.petal_width == 0.2].head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## **【問題6】図の作成**

# %%
# ラベルごとのサンプル数を円グラフにする（パーセンテージまで表示する）

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

sample_num = np.array([50, 50, 50])
label = ['Iris setosa', 'Iris virgicolor', 'Iris virginica']
plt.pie(sample_num, labels=label, counterclock=False, startangle=90,
        wedgeprops={'linewidth': 3, 'edgecolor': 'white'}, autopct='%.1f%%',
        pctdistance=0.7)
plt.axis('equal')
plt.show()

# %%
# 特徴量を一つずつ選び、箱ひげ図を使ってラベルごとのデータの分布を可視化する
# sepal_lengthについて箱ひげ図に描画する

fig = plt.figure(figsize=(20, 16))

ax1 = fig.add_subplot(2, 2, 1)
sepal_lengths = (df.iloc[:50, 0], df.iloc[50:100, 0], df.iloc[100:, 0])
ax1.boxplot(sepal_lengths)
ax1.set_xticklabels(['Iris setosa', 'Iris virgicolor', 'Iris virginica'])
plt.title('sepal length Box Plot')
plt.xlabel('species')
plt.ylabel('sepal length')
plt.ylim([4.0, 8.0])
plt.grid()

ax2 = fig.add_subplot(2, 2, 2)
sepal_widths = (df.iloc[:50, 1], df.iloc[50:100, 1], df.iloc[100:, 1])
ax2.boxplot(sepal_widths)
ax2.set_xticklabels(['Iris setosa', 'Iris virgicolor', 'Iris virginica'])
plt.title('sepal width Box Plot')
plt.xlabel('species')
plt.ylabel('sepal width')
plt.ylim([1.8, 4.5])
plt.grid()

ax3 = fig.add_subplot(2, 2, 3)
petal_lengths = (df.iloc[:50, 2], df.iloc[50:100, 2], df.iloc[100:, 2])
ax3.boxplot(petal_lengths)
ax3.set_xticklabels(['Iris setosa', 'Iris virgicolor', 'Iris virginica'])
plt.title('petal length Box Plot')
plt.xlabel('species')
plt.ylabel('petal length')
plt.ylim([0.0, 7.0])
plt.grid()

ax4 = fig.add_subplot(2, 2, 4)
petal_widths = (df.iloc[:50, 3], df.iloc[50:100, 3], df.iloc[100:, 3])
ax4.boxplot(petal_widths)
ax4.set_xticklabels(['Iris setosa', 'Iris virgicolor', 'Iris virginica'])
plt.title('petal width Box Plot')
plt.xlabel('species')
plt.ylabel('petal width')
plt.ylim([0.0, 3.0])
plt.grid()

plt.show()

# %%
# 特徴量を一つずつ選び、バイオリン図を使ってラベルごとのデータの分布を可視化する

fig = plt.figure(figsize=(20, 16))

ax1 = fig.add_subplot(2, 2, 1)
sepal_lengths = (df.iloc[:50, 0], df.iloc[50:100, 0], df.iloc[100:, 0])
ax1.violinplot(sepal_lengths)
ax1.set_xticklabels(['Iris setosa', 'Iris virgicolor', 'Iris virginica'])
plt.title('sepal length Box Plot')
plt.xlabel('species')
plt.ylabel('sepal length')
plt.ylim([4.0, 8.0])
plt.grid()

ax2 = fig.add_subplot(2, 2, 2)
petal_lengths = (df.iloc[:50, 1], df.iloc[50:100, 1], df.iloc[100:, 1])
ax2.violinplot(petal_lengths)
ax2.set_xticklabels(['Iris setosa', 'Iris virgicolor', 'Iris virginica'])
plt.title('sepal width Box Plot')
plt.xlabel('species')
plt.ylabel('sepal width')
plt.ylim([1.8, 4.5])
plt.grid()

ax3 = fig.add_subplot(2, 2, 3)
petal_widths = (df.iloc[:50, 2], df.iloc[50:100, 2], df.iloc[100:, 2])
ax3.violinplot(petal_widths)
ax3.set_xticklabels(['Iris setosa', 'Iris virgicolor', 'Iris virginica'])
plt.title('petal length Box Plot')
plt.xlabel('species')
plt.ylabel('petal length')
plt.ylim([0.0, 7.1])
plt.grid()

ax4 = fig.add_subplot(2, 2, 4)
petal_widths = (df.iloc[:50, 3], df.iloc[50:100, 3], df.iloc[100:, 3])
ax4.violinplot(petal_widths)
ax4.set_xticklabels(['Iris setosa', 'Iris virgicolor', 'Iris virginica'])
plt.title('petal width Box Plot')
plt.xlabel('species')
plt.ylabel('petal width')
plt.ylim([0.0, 3.0])
plt.grid()

plt.show()

# %% [markdown]
# ## **【問題7】特徴量間の関係の確認**

# %%
# 縦軸と横軸に特徴量を１つずつ取り、種類毎に色分けした散布図を作る

plt.figure(figsize=(20, 16))

plt.subplot(4, 4, 1)
plt.scatter(df.iloc[:, 0], df.iloc[:, 0], c='k')

plt.subplot(4, 4, 2)
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c='gray')

plt.subplot(4, 4, 3)
plt.scatter(df.iloc[:, 0], df.iloc[:, 2], c='red')

plt.subplot(4, 4, 4)
plt.scatter(df.iloc[:, 0], df.iloc[:, 3], c='olivedrab')

plt.subplot(4, 4, 5)
plt.scatter(df.iloc[:, 1], df.iloc[:, 0], c='seagreen')

plt.subplot(4, 4, 6)
plt.scatter(df.iloc[:, 1], df.iloc[:, 1], c='gold')

plt.subplot(4, 4, 7)
plt.scatter(df.iloc[:, 1], df.iloc[:, 2], c='darkgreen')

plt.subplot(4, 4, 8)
plt.scatter(df.iloc[:, 1], df.iloc[:, 3], c='royalblue')

plt.subplot(4, 4, 9)
plt.scatter(df.iloc[:, 2], df.iloc[:, 0], c='blue')

plt.subplot(4, 4, 10)
plt.scatter(df.iloc[:, 2], df.iloc[:, 1], c='plum')

plt.subplot(4, 4, 11)
plt.scatter(df.iloc[:, 2], df.iloc[:, 2], c='m')

plt.subplot(4, 4, 12)
plt.scatter(df.iloc[:, 2], df.iloc[:, 3], c='aliceblue')

plt.subplot(4, 4, 13)
plt.scatter(df.iloc[:, 3], df.iloc[:, 0], c='lightseagreen')

plt.subplot(4, 4, 14)
plt.scatter(df.iloc[:, 3], df.iloc[:, 1], c='darkcyan')

plt.subplot(4, 4, 15)
plt.scatter(df.iloc[:, 3], df.iloc[:, 2], c='silver')

plt.subplot(4, 4, 16)
plt.scatter(df.iloc[:, 3], df.iloc[:, 3], c='tan')

plt.show()

# %%
# 全ての組み合わせの散布図を一度に表示させる、散布図行列を作る
import seaborn as sns

sns.pairplot(df, hue='Species');

# %%
# 4つの特徴量に関する相関係数行列を作る

X.transpose().shape
np.corrcoef(X.transpose())
# Out:
# array([[ 1.        , -0.11756978,  0.87175378,  0.81794113],
#        [-0.11756978,  1.        , -0.4284401 , -0.36612593],
#        [ 0.87175378, -0.4284401 ,  1.        ,  0.96286543],
#        [ 0.81794113, -0.36612593,  0.96286543,  1.        ]])

# %%
# 相関係数行列のヒートマップを作る

X_names = df.columns
correlation_matrix = np.corrcoef(X.transpose())

sns.heatmap(correlation_matrix, annot=True,
            xticklabels=X_names,
            yticklabels=X_names)

plt.show()

# %% [markdown]
# ## **【問題8】可視化したグラフや表の結果の説明**

# %% [markdown]
# 　箱ひげ図やバイオリン図から、花びらの形状に関してはsetosa < virgicolor < virginicaの順番で幅も長さも大きくなる。このことから花びらの幅と長さの間には正の相関が強く見られることが予見されるが、実際に相関係数行列のグラフや数値をみると相関係数が0.96と非常に高いことが分かる。
#
# 　がく片に関しての特筆すべき点は、setosaは幅が小さく長さが大きいことから細長い形状となる一方で、virginicaは幅に対して長さがそこまで大きくないことから横に長いという点である。virgicolorについては形状に関して特徴は見られない。
#
# 　最後に特徴量間の関係について述べる。先ほども見たように花びらに関しては幅と長さに関して非常に強い相関が見られる。対してがく片については幅と長さの間にわずかな負の相関が見られるが、相関と呼べるほどのものではない。花びらの長さとがく片の長さについて強い正の相関があることから花びらの長さが大きければがく片の長さも大きく逆もまた然りである。幅についても同じような考察ができる。
